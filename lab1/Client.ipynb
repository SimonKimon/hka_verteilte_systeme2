# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script
import logging
logging.basicConfig(level=logging.DEBUG)

client = clientserver.Client() # Create a client instance

# GET
print(client.get("Alice"))

# GETALL
print(client.getall())
# Out:
# 2026-04-14 12:38:56,704 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=62, family=2, type=1, proto=0, laddr=('127.0.0.1', 43330), raddr=('127.0.0.1', 50007)>
# INFO:vs2lab.a1_layers.clientserver.Client:Client connected to socket <socket.socket fd=62, family=2, type=1, proto=0, laddr=('127.0.0.1', 43330), raddr=('127.0.0.1', 50007)>
# 2026-04-14 12:38:56,709 - vs2lab.a1_layers.clientserver.Client - INFO - GET(Alice) = NOT FOUND
# INFO:vs2lab.a1_layers.clientserver.Client:GET(Alice) = NOT FOUND
# 2026-04-14 12:38:56,714 - vs2lab.a1_layers.clientserver.Client - INFO - GETALL result erhalen
# INFO:vs2lab.a1_layers.clientserver.Client:GETALL result erhalen
# NOT FOUND
# {'Radek': '0721-111111', 'Pius': '0721-222222', 'Joel': '0721-333333', 'Philipp': '0721-444444', 'Simon': '0721-555555'}

# %% [markdown]
# Finished.
