# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script
import logging
logging.basicConfig(level=logging.DEBUG)

client = clientserver.Client() # Create a client instance

# GET
print(client.get("Alice"))

# GETALL
print(client.getall())
# Out:
# 2026-04-14 12:32:23,473 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 41270), raddr=('127.0.0.1', 50007)>
# INFO:vs2lab.a1_layers.clientserver.Client:Client connected to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 41270), raddr=('127.0.0.1', 50007)>
# 2026-04-14 12:32:23,476 - vs2lab.a1_layers.clientserver.Client - INFO - GET(Alice) = 0721-111111
# INFO:vs2lab.a1_layers.clientserver.Client:GET(Alice) = 0721-111111
# 2026-04-14 12:32:23,482 - vs2lab.a1_layers.clientserver.Client - INFO - GETALL result erhalen
# INFO:vs2lab.a1_layers.clientserver.Client:GETALL result erhalen
# 0721-111111
# {'Alice': '0721-111111', 'Bob': '0721-222222', 'Carol': '0721-333333', 'David': '0721-444444'}

# %% [markdown]
# Finished.
